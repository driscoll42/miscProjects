# %%
from bs4 import BeautifulSoup
import pandas as pd
import re
import os
import json
from time import sleep
import requests_cache
from functools import reduce
from requests_cache import NEVER_EXPIRE

# %%
def parse_html(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    tables = soup.find_all('table')

    data = []

    for table in tables:
        category = table.find('h3').text.strip()
        rows = table.find_all('tr')[1:]  # Skip the title row

        for row in rows:
            feature = row.find('th').text.strip()
            value = row.find('td').text.strip()
            if not value and 'class' in row.find('td').attrs:
                value = 'Yes' if 'yes' in row.find('td')['class'] else 'No'
            data.append({'Category': category, 'Feature': feature, 'Value': value})

    return pd.DataFrame(data)

# %%
def request_function(url, agent_list, session):
    attempts = 5

    while attempts > 0:
        random_agent_row = agent_list.sample()
        random_agent = random_agent_row['Agent'].item()
        response = session.get(url, headers={'User-Agent': random_agent})

        content = response.text
        if '<title>Garmin | Page not found</title>' in content:
            print(attempts, 'Unused Page')
            return 'Error - Unused Page', pd.DataFrame()
        elif 'Access Denied' in content:
            print(attempts, 'Access Denied')
            session.cache.delete_url(url)
            print(attempts, 'Access Denied')
        elif 'var GarminAppBootstrap' in content:
            return 'Data Found', content
        attempts -= 1
        sleep(5)
    return 'Error - attempts ran out', pd.DataFrame()

# %%
def parse_spec_page(content, url):
    soup = BeautifulSoup(content, 'html.parser')

    garmin_app_bootstrap = soup.find('div', id='garmin-app-bootstrap')
    try:
        g_scipt = garmin_app_bootstrap.find('script')
    except Exception as e:
        print(content)
        print(e)
        raise AttributeError

    match = re.search(r'var GarminAppBootstrap = ({.*?});\s*\n', g_scipt.text, re.DOTALL)

    dict_data = match.group(1)

    data = json.loads(dict_data)

    main_sku = data['sku']
    skus = data['skus']

    seoAttributes = data['seoAttributes']
    # print(seoAttributes)

    product_attributes = skus[main_sku]

    productName = product_attributes['productName']
    productVariation = product_attributes['productVariation']
    productId = product_attributes['productId']
    try:
        price = product_attributes['price']['price']['price']
    except Exception as e:
        price = ''
    image_link = product_attributes['seo']['ogImage']

    specs = product_attributes['tabs']['specsTab']['content']
    spec_df = parse_html(specs)
    # Add product name and variation to the spec_df as new rows with a Category of 'Product Info' using concat
    # make a small dataframe with the product name and variation
    df_9 = pd.DataFrame({'Category': 'Product Info', 'Feature': 'Product Name - no URL', 'Value': productName},
                        index=[0])
    df_1 = pd.DataFrame({'Category': 'Product Info', 'Feature': 'Product Name',
                         'Value'   : f"""HYPERLINK("{url}", "{productName}")"""}, index=[0])
    df_2 = pd.DataFrame({'Category': 'Product Info', 'Feature': 'Product Variation', 'Value': productVariation},
                        index=[0])
    df_3 = pd.DataFrame({'Category': 'Product Info', 'Feature': 'Product ID', 'Value': productId}, index=[0])
    df_4 = pd.DataFrame({'Category': 'Product Info', 'Feature': 'Main SKU', 'Value': main_sku}, index=[0])
    # df_5 = pd.DataFrame({'Category': 'Product Info', 'Feature': 'Image Link', 'Value': image_link}, index=[0])
    df_8 = pd.DataFrame({'Category': 'Product Info', 'Feature': 'Image', 'Value': f"""IMAGE("{image_link}")"""},
                        index=[0])
    df_6 = pd.DataFrame({'Category': 'Product Info', 'Feature': 'Product URL', 'Value': url}, index=[0])
    df_7 = pd.DataFrame({'Category': 'Product Info', 'Feature': 'Price', 'Value': price}, index=[0])

    spec_df = pd.concat([df_1, df_2, df_3, df_4, df_6, df_7, df_8, df_9, spec_df], ignore_index=True)
    spec_df = spec_df.rename(columns={'Value': productName})
    return productName, spec_df

# %%
def get_live_data(id, session, agent_list, gb_list=[], au_list=[], debug=False):
    if id in gb_list:
        url = f'https://www.garmin.com/en-GB/p/{id}'
    elif id in au_list:
        url = f'https://www.garmin.com/en-AU/p/{id}'
    else:
        url = f'https://www.garmin.com/en-US/p/{id}'
    if debug: print(url)

    err_text, content = request_function(url, agent_list, session)
    if 'Error - attempts ran out' in err_text:
        print(err_text)
        raise Exception
    elif 'Error - Unused Page' in err_text:
        return 'Unused Page', pd.DataFrame()

    productName, spec_df = parse_spec_page(content, url)
    return productName, spec_df

# %%
ids = [662694, 662825, 742133, 785411, 665374, 667002, 667005, 672620, 270, 27335, 595326, 104012, 10527, 1055469,
       1057989, 107143, 107272, 108731, 10884, 10885, 11039, 112885, 112912, 1196129, 120680, 122785, 1228171,
       1228429, 1228493, 126596, 1277573, 129397, 1297277, 1300797, 1323517, 134491, 134596, 137024, 138810,
       1390829, 139389, 1398869, 140528, 1411809, 143405, 143677, 145621, 148289, '150767/pn/010-01297-01', 154886,
       159116, 160512, 1611937, 164366, 1652337, 166370, 230, 231, 27483, 31859, 331, 348, 349, 36728, 504038, 508487,
       508489, 512475, 512478, 516105, 516207, 519298, 522791, 523893, 527935, 529988, 531166, 532035, 532348, 538374,
       539963, 541225, 543199, 543589, 544984, 545411, 545480, 548743, 552237, 552962, 552982, 553168, 554662, 560327,
       561299, 564291, 567813, 567991, 568181, 571520, 574602, 580642, 582444, 583562, 583980, 591311, 591945, 596828,
       597253, 602063, 602068, 603201, 603229, 603267, 605172, 605739, 608567, 608613, 608618, 608665, 611037,
       611996, 612476, 621224, 621232, 621802, 621922, 623539, 623921, 628939, 632320, 633356, 633625, 633646, 633654,
       633685, 63511, 635923, 6400, 641121, 641375, 641435, 641449, 641479, 641501, 641530, 643260, 643382, 643399,
       646690, 647267, 658892, 662790, 679335, 682416, 690051, 69043, 695391, 695447, 695448, 696004, 696005, 698394,
       698436, 698519, 698632, 699548, 699976, 700437, 701618, 702797, 704417, 707174, 707225, 707506, 707538, 707572,
       711488, 713363, 714945, 715736, 715870, 716891, 721216, 725447, 730659, 731136, 733535, 739416, 741137, 741374,
       741438, 741462, 742152, 742170, 742174, 742207, 743387, 760778, 761998, 766516, 766565, 775357, 775421, 775697,
       775739, 777655, 777730, 780139, 780165, 780196, 782585, 783441, 783448, 783461, 783465, 783467, 798161, 798777,
       798925, 798926, 798938, 798946, 801643, 802162, 802703, 802901, 802925, 815409, 815448, 815582, 818345, 818387,
       819546, 819727, 819761, 83068, 83274, 83280, 84374, 847697, 847706, 851039, 852159, 852183, 852217, 854515,
       869433, 873008, 873214, 884088, 884198, 884292, 884414, 884585, 886689, 886725, 886785, 894039, 894067, 905283,
       90671, 90675, 950157, 950277, 97287, 681612, 735611, 865822, 1479414, 735563, 1132094, 770963, 649059, 512311,
       530376, 136403, 719696, 711538, 530464, 679362, 658593, 699171, 658594, 658586, 699230, 658661, 573589,
       606555, 518151, 721258, 698001, 669024, 550821, 601468, 885302, 701670, 734868, 690885, 874099,
       690887, 690888, 690890, 690886, 690885, 742197, 815332, 866230, 1479413, 735520, 866139, 865925,
       735542, 866191, 865945, 682155, 260, 257, 30026, 30025, 572639, 583825, 858933, 859036, 681757, 637006, 711489]

gb_list = [573589, 707538, 761998, 532348, 612476, 633356, 690051, 707225, 707538, 715736, 761998, 633356]

au_list = [530376, 136403, 682155]

# vectors = [510941, 167943, 93569] - Don't have the same kind of spec layout

# 600380 - a vivofit Jr 2 First Order that is not saved anywehre in English
# 696564 - A Tacx Genius Trainer, too old to have a normal page
# 696562 - A Tacx Bushido Trainer, too old to have a normal page
# 697357 - A Tacx Neo Smart Trainer, too old to have a normal page
# 696563 - A Tacx FLUX Smart Trainer, too old to have a normal page
# 305658 - HRM PRo for the US, doesn't work anymore, 682155 does fur en-AU

# initialize the dataframe with columns Category, Feature, and Value
df = pd.DataFrame(columns=['Category', 'Feature'])

agent_list = pd.read_excel('agent_list.xlsx', engine='openpyxl')

debug = True

session = requests_cache.CachedSession('garmin_cache')
session.settings.expire_after = NEVER_EXPIRE

dfs = []

for id in ids:
    productName, id_df = get_live_data(id, session, agent_list, gb_list, au_list, debug)
    # join the dataframes together based on matching the Category and Feature columns
    if debug: print(id, productName)
    # check if productName is not one of the error messages
    if productName not in ['Unused Page', 'Access Denied']:
        dfs.append(id_df)

# iterate over all files in the saved_htmls folder
for file in os.listdir('saved_htmls'):
    with open(f'saved_htmls/{file}', 'r', encoding='utf-8') as f:
        content = f.read()
    file_name = file.split('.')[0]
    productName, id_df = parse_spec_page(content, f'https://www.garmin.com/en-US/p/{file_name}')
    if debug: print(file, productName)
    dfs.append(id_df)

# merge the dataframes together based on matching the Category and Feature columns

df = reduce(lambda left, right: pd.merge(left, right, on=['Category', 'Feature'], how='outer'), dfs)

# sort all the columns in the dataframe except for the first two columns
first_two = df.columns[:2].tolist()
sorted_rest = sorted(df.columns[2:])
new_order = first_two + sorted_rest
df = df.reindex(columns=new_order)
# Out:
# https://www.garmin.com/en-US/p/662694
# 662694 vívomove® Luxe
# https://www.garmin.com/en-US/p/662825
# 662825 vívomove® Style
# https://www.garmin.com/en-US/p/742133
# 742133 vívomove® Sport
# https://www.garmin.com/en-US/p/785411
# 785411 vívomove® Trend
# https://www.garmin.com/en-US/p/665374
# 665374 Garmin Swim™ 2
# https://www.garmin.com/en-US/p/667002
# 667002 Rey™
# https://www.garmin.com/en-US/p/667005
# 667005 Captain Marvel
# https://www.garmin.com/en-US/p/672620
# 672620 Approach® Z82
# https://www.garmin.com/en-US/p/270
# 270 Forerunner® 301
# https://www.garmin.com/en-US/p/27335
# 27335 Forerunner® 310XT
# https://www.garmin.com/en-US/p/595326
# 595326 quatix® 5 Sapphire
# https://www.garmin.com/en-US/p/104012
# 104012 FR70
# https://www.garmin.com/en-US/p/10527
# 10527 Forerunner® 50
# https://www.garmin.com/en-US/p/1055469
# 1055469 Forerunner® 165
# https://www.garmin.com/en-US/p/1057989
# 1057989 vívoactive® 5
# https://www.garmin.com/en-US/p/107143
# 107143 Forerunner® 10
# https://www.garmin.com/en-US/p/107272
# 107272 fēnix®
# https://www.garmin.com/en-US/p/108731
# 108731 Approach® S3
# https://www.garmin.com/en-US/p/10884
# 10884 Edge® 605
# https://www.garmin.com/en-US/p/10885
# 10885 Edge® 705
# https://www.garmin.com/en-US/p/11039
# 11039 Forerunner® 405
# https://www.garmin.com/en-US/p/112885
# 112885 Edge® 510
# https://www.garmin.com/en-US/p/112912
# 112912 Edge® 810
# https://www.garmin.com/en-US/p/1196129
# 1196129 Edge® 1050
# https://www.garmin.com/en-US/p/120680
# 120680 quatix®
# https://www.garmin.com/en-US/p/122785
# 122785 Forerunner® 620
# https://www.garmin.com/en-US/p/1228171
# 1228171 fēnix® 8 – 51 mm, AMOLED
# https://www.garmin.com/en-US/p/1228429
# 1228429 fēnix® 8 – 47 mm, AMOLED
# https://www.garmin.com/en-US/p/1228493
# 1228493 fēnix® 8 – 43 mm, AMOLED
# https://www.garmin.com/en-US/p/126596
# 126596 Approach® S2
# https://www.garmin.com/en-US/p/1277573
# 1277573 quatix® 7 Pro
# https://www.garmin.com/en-US/p/129397
# 129397 Forerunner® 220
# https://www.garmin.com/en-US/p/1297277
# 1297277 tactix® 7 – AMOLED Edition
# https://www.garmin.com/en-US/p/1300797
# 1300797 Descent™ G1 Solar - Ocean Edition
# https://www.garmin.com/en-US/p/1323517
# 1323517 MARQ® Athlete (Gen 2) - Performance Edition
# https://www.garmin.com/en-US/p/134491
# 134491 Edge® 1000
# https://www.garmin.com/en-US/p/134596
# 134596 Edge® Touring
# https://www.garmin.com/en-US/p/137024
# 137024 Forerunner® 920XT
# https://www.garmin.com/en-US/p/138810
# 138810 Approach® S6
# https://www.garmin.com/en-US/p/1390829
# 1390829 fēnix® 8 – 51 mm, Solar
# https://www.garmin.com/en-US/p/139389
# 139389 tactix®
# https://www.garmin.com/en-US/p/1398869
# 1398869 D2™ Mach 1 Pro
# https://www.garmin.com/en-US/p/140528
# 140528 Approach® S4
# https://www.garmin.com/en-US/p/1411809
# 1411809 Approach® Z30
# https://www.garmin.com/en-US/p/143405
# 143405 vívofit®
# https://www.garmin.com/en-US/p/143677
# 143677 Edge® Touring Plus
# https://www.garmin.com/en-US/p/145621
# 145621 Forerunner® 15
# https://www.garmin.com/en-US/p/148289
# 148289 D2™
# https://www.garmin.com/en-US/p/150767/pn/010-01297-01
# 150767/pn/010-01297-01 vívoactive®
# https://www.garmin.com/en-US/p/154886
# 154886 vívosmart®
# https://www.garmin.com/en-US/p/159116
# 159116 fēnix® 2
# https://www.garmin.com/en-US/p/160512
# 160512 fēnix® 3
# https://www.garmin.com/en-US/p/1611937
# 1611937 Forerunner® 165 Music
# https://www.garmin.com/en-US/p/164366
# 164366 Forerunner® 25
# https://www.garmin.com/en-US/p/1652337
# 1652337 fēnix® E – 47 mm, AMOLED
# https://www.garmin.com/en-US/p/166370
# 166370 Edge® 520
# https://www.garmin.com/en-US/p/230
# 230 Forerunner® 201
# https://www.garmin.com/en-US/p/231
# 231 Forerunner® 101
# https://www.garmin.com/en-US/p/27483
# 27483 FR60
# https://www.garmin.com/en-US/p/31859
# 31859 Forerunner® 405CX
# https://www.garmin.com/en-US/p/331
# 331 Edge® 305
# https://www.garmin.com/en-US/p/348
# 348 Forerunner® 205
# https://www.garmin.com/en-US/p/349
# 349 Forerunner® 305
# https://www.garmin.com/en-US/p/36728
# 36728 Edge® 500
# https://www.garmin.com/en-US/p/504038
# 504038 vívofit® 2
# https://www.garmin.com/en-US/p/508487
# 508487 Edge® 20
# https://www.garmin.com/en-US/p/508489
# 508489 Edge® 25
# https://www.garmin.com/en-US/p/512475
# 512475 Approach® S5
# https://www.garmin.com/en-US/p/512478
# 512478 Forerunner® 225
# https://www.garmin.com/en-US/p/516105
# 516105 Forerunner® 630
# https://www.garmin.com/en-US/p/516207
# 516207 Approach® S20
# https://www.garmin.com/en-US/p/519298
# 519298 Approach® X40
# https://www.garmin.com/en-US/p/522791
# 522791 Edge® Explore 1000
# https://www.garmin.com/en-US/p/523893
# 523893 Forerunner® 230
# https://www.garmin.com/en-US/p/527935
# 527935 D2™ Bravo
# https://www.garmin.com/en-US/p/529988
# 529988 Forerunner® 235
# https://www.garmin.com/en-US/p/531166
# 531166 vívosmart® HR
# https://www.garmin.com/en-US/p/532035
# 532035 fēnix® Chronos
# https://www.garmin.com/en-GB/p/532348
# 532348 vívomove®
# https://www.garmin.com/en-US/p/538374
# 538374 vívoactive® HR
# https://www.garmin.com/en-US/p/539963
# 539963 vívofit® 3
# https://www.garmin.com/en-US/p/541225
# 541225 Forerunner® 735XT
# https://www.garmin.com/en-US/p/543199
# 543199 Edge® 820
# https://www.garmin.com/en-US/p/543589
# 543589 tactix® Bravo
# https://www.garmin.com/en-US/p/544984
# 544984 vívofit® jr.
# https://www.garmin.com/en-US/p/545411
# 545411 quatix® 3
# https://www.garmin.com/en-US/p/545480
# 545480  fēnix® 3 HR
# https://www.garmin.com/en-US/p/548743
# 548743 vívosmart® HR+
# https://www.garmin.com/en-US/p/552237
# 552237 fēnix® 5S
# https://www.garmin.com/en-US/p/552962
# 552962 Forerunner® 35
# https://www.garmin.com/en-US/p/552982
# 552982 fēnix® 5
# https://www.garmin.com/en-US/p/553168
# 553168 Approach® G30
# https://www.garmin.com/en-US/p/554662
# 554662 Approach® S60
# https://www.garmin.com/en-US/p/560327
# 560327 fēnix® 5X
# https://www.garmin.com/en-US/p/561299
# 561299 Edge® Explore 820
# https://www.garmin.com/en-US/p/564291
# 564291 Forerunner® 935
# https://www.garmin.com/en-US/p/567813
# 567813 vívosmart® 3
# https://www.garmin.com/en-US/p/567991
# 567991 Edge® 1030
# https://www.garmin.com/en-US/p/568181
# 568181 Descent™ Mk1
# https://www.garmin.com/en-US/p/571520
# 571520 vívoactive® 3
# https://www.garmin.com/en-US/p/574602
# 574602 vívosport®
# https://www.garmin.com/en-US/p/580642
# 580642 quatix® 5
# https://www.garmin.com/en-US/p/582444
# 582444 vívofit® 4
# https://www.garmin.com/en-US/p/583562
# 583562 vívomove® HR
# https://www.garmin.com/en-US/p/583980
# 583980 Approach® X10
# https://www.garmin.com/en-US/p/591311
# 591311 Forerunner® 645
# https://www.garmin.com/en-US/p/591945
# 591945 D2™ Charlie
# https://www.garmin.com/en-US/p/596828
# 596828 Edge® 130
# https://www.garmin.com/en-US/p/597253
# 597253 Approach® G80
# https://www.garmin.com/en-US/p/602063
# 602063 vívoactive® 3 Music (Verizon)
# https://www.garmin.com/en-US/p/602068
# 602068 vívoactive® 3 Music
# https://www.garmin.com/en-US/p/603201
# 603201 fēnix® 5S Plus
# https://www.garmin.com/en-US/p/603229
# 603229 fēnix® 5X Plus
# https://www.garmin.com/en-US/p/603267
# 603267 fēnix® 5 Plus
# https://www.garmin.com/en-US/p/605172
# 605172 Approach® CT10 - Full Set
# https://www.garmin.com/en-US/p/605739
# 605739 vívosmart® 4
# https://www.garmin.com/en-US/p/608567
# 608567 MARQ® Aviator
# https://www.garmin.com/en-US/p/608613
# 608613 MARQ® Commander
# https://www.garmin.com/en-US/p/608618
# 608618 MARQ® Captain
# https://www.garmin.com/en-US/p/608665
# 608665 MARQ® Driver
# https://www.garmin.com/en-US/p/611037
# 611037 Approach® S10
# https://www.garmin.com/en-US/p/611996
# 611996 Edge Explore
# https://www.garmin.com/en-GB/p/612476
# 612476 Forerunner® 645 Music
# https://www.garmin.com/en-US/p/621224
# 621224 Edge® 530
# https://www.garmin.com/en-US/p/621232
# 621232 Edge® 830
# https://www.garmin.com/en-US/p/621802
# 621802 Instinct® – Standard Edition
# https://www.garmin.com/en-US/p/621922
# 621922 Forerunner® 945
# https://www.garmin.com/en-US/p/623539
# 623539 Edge® 520 Plus
# https://www.garmin.com/en-US/p/623921
# 623921 tactix® Charlie
# https://www.garmin.com/en-US/p/628939
# 628939 Forerunner® 245
# https://www.garmin.com/en-US/p/632320
# 632320 Descent™ Mk2i
# https://www.garmin.com/en-GB/p/633356
# 633356 Descent™ Mk2
# https://www.garmin.com/en-US/p/633625
# 633625 MARQ® Athlete
# https://www.garmin.com/en-US/p/633646
# 633646 D2™ Delta PX
# https://www.garmin.com/en-US/p/633654
# 633654 D2™ Delta
# https://www.garmin.com/en-US/p/633685
# 633685 D2™ Delta S
# https://www.garmin.com/en-US/p/63511
# 63511 Forerunner® 110
# https://www.garmin.com/en-US/p/635923
# 635923 Approach® S40
# https://www.garmin.com/en-US/p/6400
# 6400 Edge® 205
# https://www.garmin.com/en-US/p/641121
# 641121 Forerunner® 45
# https://www.garmin.com/en-US/p/641375
# 641375 fēnix® 6X - Pro Solar Edition
# https://www.garmin.com/en-US/p/641435
# 641435 fēnix® 6X - Pro and Sapphire Editions
# https://www.garmin.com/en-US/p/641449
# 641449 fēnix® 6 – Standard Edition
# https://www.garmin.com/en-US/p/641479
# 641479 fēnix® 6 - Pro and Sapphire Editions
# https://www.garmin.com/en-US/p/641501
# 641501 fēnix® 6S – Standard Edition
# https://www.garmin.com/en-US/p/641530
# 641530 fēnix® 6S - Pro and Sapphire Editions
# https://www.garmin.com/en-US/p/643260
# 643260 Venu®
# https://www.garmin.com/en-US/p/643382
# 643382 vívoactive® 4
# https://www.garmin.com/en-US/p/643399
# 643399 vívoactive® 4S
# https://www.garmin.com/en-US/p/646690
# 646690 Forerunner® 245 Music
# https://www.garmin.com/en-US/p/647267
# 647267 Approach® S62
# https://www.garmin.com/en-US/p/658892
# 658892 Forerunner® 30
# https://www.garmin.com/en-US/p/662790
# 662790 vívomove® 3S
# https://www.garmin.com/en-US/p/679335
# 679335 Instinct® Solar  – Standard Edition
# https://www.garmin.com/en-US/p/682416
# 682416 Forerunner® 45S
# https://www.garmin.com/en-GB/p/690051
# 690051 Instinct® – Tactical Edition
# https://www.garmin.com/en-US/p/69043
# 69043 Edge® 800
# https://www.garmin.com/en-US/p/695391
# 695391 Approach® R10
# https://www.garmin.com/en-US/p/695447
# 695447 First Avenger
# https://www.garmin.com/en-US/p/695448
# 695448 Darth Vader™
# https://www.garmin.com/en-US/p/696004
# 696004 tactix® Delta - Solar Edition
# https://www.garmin.com/en-US/p/696005
# 696005 tactix® Delta - Sapphire Edition
# https://www.garmin.com/en-US/p/698394
# 698394 vívomove® 3
# https://www.garmin.com/en-US/p/698436
# 698436 Edge® 130 Plus
# https://www.garmin.com/en-US/p/698519
# 698519 Lily® - Sport Edition
# https://www.garmin.com/en-US/p/698632
# 698632 Forerunner® 945 LTE
# https://www.garmin.com/en-US/p/699548
# 699548 MARQ® Adventurer
# https://www.garmin.com/en-US/p/699976
# 699976 quatix® 6
# https://www.garmin.com/en-US/p/700437
# 700437 MARQ® Golfer
# https://www.garmin.com/en-US/p/701618
# 701618 Descent™ Mk2S
# https://www.garmin.com/en-US/p/702797
# 702797 Enduro™
# https://www.garmin.com/en-US/p/704417
# 704417 Edge® 1030 Plus
# https://www.garmin.com/en-US/p/707174
# 707174 Venu® Sq
# https://www.garmin.com/en-GB/p/707225
# 707225 Venu Sq Music Edition
# https://www.garmin.com/en-US/p/707506
# 707506 D2™ Air
# https://www.garmin.com/en-GB/p/707538
# 707538 Venu® 2
# https://www.garmin.com/en-US/p/707572
# 707572 Venu® 2S
# https://www.garmin.com/en-US/p/711488
# 711488 vívofit® jr. 3 – Marvel
# https://www.garmin.com/en-US/p/713363
# 713363 Forerunner® 745
# https://www.garmin.com/en-US/p/714945
# 714945 Bounce™
# https://www.garmin.com/en-GB/p/715736
# 715736 Instinct® Solar – Surf Edition
# https://www.garmin.com/en-US/p/715870
# 715870 MARQ® Captain: American Magic Edition
# https://www.garmin.com/en-US/p/716891
# 716891 Instinct® Solar – Tactical Edition
# https://www.garmin.com/en-US/p/721216
# 721216 Approach® S12
# https://www.garmin.com/en-US/p/725447
# 725447 quatix® 6X Solar
# https://www.garmin.com/en-US/p/730659
# 730659 Venu® 2 Plus
# https://www.garmin.com/en-US/p/731136
# 731136 Edge® 1040 Solar
# https://www.garmin.com/en-US/p/733535
# 733535 tactix® Delta - Solar Edition with Ballistics
# https://www.garmin.com/en-US/p/739416
# 739416 Approach® G12
# https://www.garmin.com/en-US/p/741137
# 741137 Forerunner® 55
# https://www.garmin.com/en-US/p/741374
# 741374 Instinct® 2S - Standard Edition
# https://www.garmin.com/en-US/p/741438
# 741438 Instinct® 2S - Camo Edition
# https://www.garmin.com/en-US/p/741462
# 741462 Instinct® 2S Solar
# https://www.garmin.com/en-US/p/742152
# 742152 MARQ® Adventurer Performance Edition
# https://www.garmin.com/en-US/p/742170
# 742170 MARQ® Driver Performance Edition
# https://www.garmin.com/en-US/p/742174
# 742174 MARQ® Athlete Performance Edition
# https://www.garmin.com/en-US/p/742207
# 742207 MARQ® Aviator Performance Edition
# https://www.garmin.com/en-US/p/743387
# 743387 Approach® S42
# https://www.garmin.com/en-US/p/760778
# 760778 epix™ (Gen 2) – Sapphire Edition | 47 mm
# https://www.garmin.com/en-GB/p/761998
# 761998 Instinct® – Esports Edition
# https://www.garmin.com/en-US/p/766516
# 766516 Descent™ G1
# https://www.garmin.com/en-US/p/766565
# 766565 Descent™ G1 Solar
# https://www.garmin.com/en-US/p/775357
# 775357 Instinct® 2 - Camo Edition
# https://www.garmin.com/en-US/p/775421
# 775421 Instinct® 2 - Standard Edition
# https://www.garmin.com/en-US/p/775697
# 775697 Instinct® 2 Solar
# https://www.garmin.com/en-US/p/775739
# 775739 Instinct® 2 Solar - Tactical Edition
# https://www.garmin.com/en-US/p/777655
# 777655 Forerunner® 955
# https://www.garmin.com/en-US/p/777730
# 777730 Forerunner® 955 Solar
# https://www.garmin.com/en-US/p/780139
# 780139 Forerunner® 255
# https://www.garmin.com/en-US/p/780165
# 780165 Forerunner® 255S
# https://www.garmin.com/en-US/p/780196
# 780196 Forerunner® 255 Music
# https://www.garmin.com/en-US/p/782585
# 782585 vívosmart® 5
# https://www.garmin.com/en-US/p/783441
# 783441 MARQ® Captain (Gen 2)
# https://www.garmin.com/en-US/p/783448
# 783448 MARQ® Athlete (Gen 2)
# https://www.garmin.com/en-US/p/783461
# 783461 MARQ® Aviator (Gen 2)
# https://www.garmin.com/en-US/p/783465
# 783465 MARQ® Golfer (Gen 2)
# https://www.garmin.com/en-US/p/783467
# 783467 MARQ® Adventurer (Gen 2)
# https://www.garmin.com/en-US/p/798161
# 798161 Approach® CT10 - Starter Pack
# https://www.garmin.com/en-US/p/798777
# 798777 Edge® 840
# https://www.garmin.com/en-US/p/798925
# 798925 Edge® 540 Solar
# https://www.garmin.com/en-US/p/798926
# 798926 D2™ Mach 1
# https://www.garmin.com/en-US/p/798938
# 798938 Edge® 540
# https://www.garmin.com/en-US/p/798946
# 798946 Edge® 840 Solar
# https://www.garmin.com/en-US/p/801643
# 801643 Venu® Sq 2
# https://www.garmin.com/en-US/p/802162
# 802162 Edge® Explore 2
# https://www.garmin.com/en-US/p/802703
# 802703 tactix® 7 – Pro Edition
# https://www.garmin.com/en-US/p/802901
# 802901 tactix® 7 – Pro Ballistics Edition
# https://www.garmin.com/en-US/p/802925
# 802925 tactix® 7 – Standard Edition
# https://www.garmin.com/en-US/p/815409
# 815409 MARQ® Golfer (Gen 2) - Carbon Edition
# https://www.garmin.com/en-US/p/815448
# 815448 MARQ® Athlete (Gen 2) - Carbon Edition
# https://www.garmin.com/en-US/p/815582
# 815582 MARQ® Commander (Gen 2) - Carbon Edition
# https://www.garmin.com/en-US/p/818345
# 818345 quatix® 7X – Solar Edition
# https://www.garmin.com/en-US/p/818387
# 818387 quatix® 7 – Standard Edition
# https://www.garmin.com/en-US/p/819546
# 819546 Instinct® Crossover Solar - Tactical Edition
# https://www.garmin.com/en-US/p/819727
# 819727 Instinct® Crossover Solar
# https://www.garmin.com/en-US/p/819761
# 819761 Instinct® Crossover - Standard Edition
# https://www.garmin.com/en-US/p/83068
# 83068 Approach® S1
# https://www.garmin.com/en-US/p/83274
# 83274 Forerunner® 410
# https://www.garmin.com/en-US/p/83280
# 83280 Forerunner® 210
# https://www.garmin.com/en-US/p/84374
# 84374 Forerunner® 610
# https://www.garmin.com/en-US/p/847697
# 847697 Approach® S70 - 42 mm
# https://www.garmin.com/en-US/p/847706
# 847706 Approach® S70 - 47 mm
# https://www.garmin.com/en-US/p/851039
# 851039 Enduro™ 3
# https://www.garmin.com/en-US/p/852159
# 852159 Descent™ Mk3i – 51 mm
# https://www.garmin.com/en-US/p/852183
# 852183 Descent™ Mk3 – 43 mm
# https://www.garmin.com/en-US/p/852217
# 852217 Descent™ Mk3i – 43 mm
# https://www.garmin.com/en-US/p/854515
# 854515 Enduro™ 2
# https://www.garmin.com/en-US/p/869433
# 869433 D2™ Air X10
# https://www.garmin.com/en-US/p/873008
# 873008 Venu® 3
# https://www.garmin.com/en-US/p/873214
# 873214 Venu® 3S
# https://www.garmin.com/en-US/p/884088
# 884088 epix™ Pro (Gen 2) – Sapphire Edition | 51 mm
# https://www.garmin.com/en-US/p/884198
# 884198 epix™ Pro (Gen 2) – Standard Edition | 42 mm
# https://www.garmin.com/en-US/p/884292
# 884292 epix™ Pro (Gen 2) – Standard Edition | 47 mm
# https://www.garmin.com/en-US/p/884414
# 884414 Instinct® 2X Solar - Tactical Edition
# https://www.garmin.com/en-US/p/884585
# 884585 Instinct® 2X Solar
# https://www.garmin.com/en-US/p/886689
# 886689 Forerunner® 265S
# https://www.garmin.com/en-US/p/886725
# 886725 Forerunner® 965
# https://www.garmin.com/en-US/p/886785
# 886785 Forerunner® 265
# https://www.garmin.com/en-US/p/894039
# 894039 epix™ Pro (Gen 2) – Sapphire Edition | 42 mm
# https://www.garmin.com/en-US/p/894067
# 894067 epix™ Pro (Gen 2) – Sapphire Edition | 47 mm
# https://www.garmin.com/en-US/p/905283
# 905283 epix™ Pro (Gen 2) – Standard Edition | 51 mm
# https://www.garmin.com/en-US/p/90671
# 90671 Forerunner® 910XT
# https://www.garmin.com/en-US/p/90675
# 90675 Edge® 200
# https://www.garmin.com/en-US/p/950157
# 950157 Lily® 2 Classic
# https://www.garmin.com/en-US/p/950277
# 950277 Lily® 2
# https://www.garmin.com/en-US/p/97287
# 97287 Garmin Swim™
# https://www.garmin.com/en-US/p/681612
# 681612 vívofit® jr. 2 – Disney Frozen 2
# https://www.garmin.com/en-US/p/735611
# 735611 fēnix® 7 – Standard Edition
# https://www.garmin.com/en-US/p/865822
# 865822 fēnix® 7 Pro – Solar Edition
# https://www.garmin.com/en-US/p/1479414
# 1479414 fēnix® 7X Pro – Solar Edition (No Wi-Fi®)
# https://www.garmin.com/en-US/p/735563
# 735563 fēnix® 7X – Sapphire Solar Edition
# https://www.garmin.com/en-US/p/1132094
# 1132094 HRM-Fit™
# https://www.garmin.com/en-US/p/770963
# 770963 HRM-Pro™ Plus
# https://www.garmin.com/en-US/p/649059
# 649059 HRM-Dual™
# https://www.garmin.com/en-US/p/512311
# 512311 HRM-Swim™
# https://www.garmin.com/en-AU/p/530376
# 530376 HRM-Run™
# https://www.garmin.com/en-AU/p/136403
# 136403 HRM-Tri™
# https://www.garmin.com/en-US/p/719696
# 719696 Lily® - Classic Edition
# https://www.garmin.com/en-US/p/711538
# 711538 vívofit® jr. 3 – Garmin
# https://www.garmin.com/en-US/p/530464
# 530464 Garmin Index™ Smart Scale
# https://www.garmin.com/en-US/p/679362
# 679362 Index™ S2 Smart Scale
# https://www.garmin.com/en-US/p/658593
# 658593 Rally™ RS200
# https://www.garmin.com/en-US/p/699171
# 699171 Rally™ RK200
# https://www.garmin.com/en-US/p/658594
# 658594 Rally™ XC200
# https://www.garmin.com/en-US/p/658586
# 658586 Rally™ XC100
# https://www.garmin.com/en-US/p/699230
# 699230 Rally™ RK100
# https://www.garmin.com/en-US/p/658661
# 658661 Rally™ RS100
# https://www.garmin.com/en-GB/p/573589
# 573589 Vector™ 3
# https://www.garmin.com/en-US/p/606555
# 606555 Vector™ 3S
# https://www.garmin.com/en-US/p/518151
# 518151 Varia™ Rearview Radar
# https://www.garmin.com/en-US/p/721258
# 721258 Varia™ RCT715
# https://www.garmin.com/en-US/p/698001
# 698001 Varia™ RTL515
# https://www.garmin.com/en-US/p/669024
# 669024 Varia™ RVR315
# https://www.garmin.com/en-US/p/550821
# 550821 Varia™ UT800 Smart Headlight
# https://www.garmin.com/en-US/p/601468
# 601468 Varia™ RTL510
# https://www.garmin.com/en-US/p/885302
# 885302 Tacx® NEO 3M Smart Trainer
# https://www.garmin.com/en-US/p/701670
# 701670 Tacx® NEO 2T Smart Trainer
# https://www.garmin.com/en-US/p/734868
# 734868 Tacx® NEO Bike Plus
# https://www.garmin.com/en-US/p/690885
# 690885 Tacx® NEO Bike Smart Trainer
# https://www.garmin.com/en-US/p/874099
# 874099 Varia™ eRTL615
# https://www.garmin.com/en-US/p/690887
# 690887 Tacx® FLUX 2 Smart Trainer
# https://www.garmin.com/en-US/p/690888
# 690888 Tacx® FLUX S Smart Trainer
# https://www.garmin.com/en-US/p/690890
# 690890 Tacx® Flow Smart Trainer
# https://www.garmin.com/en-US/p/690886
# 690886 Tacx® NEO 2 Smart Trainer
# https://www.garmin.com/en-US/p/690885
# 690885 Tacx® NEO Bike Smart Trainer
# https://www.garmin.com/en-US/p/742197
# 742197 Tacx® Boost
# https://www.garmin.com/en-US/p/815332
# 815332 Tacx® NEO Motion Plates
# https://www.garmin.com/en-US/p/866230
# 866230 fēnix® 7X Pro – Sapphire Solar Edition
# https://www.garmin.com/en-US/p/1479413
# 1479413 fēnix® 7 Pro – Solar Edition (No Wi-Fi®)
# https://www.garmin.com/en-US/p/735520
# 735520 fēnix® 7 – Sapphire Solar Edition
# https://www.garmin.com/en-US/p/866139
# 866139 fēnix® 7S Pro – Sapphire Solar Edition
# https://www.garmin.com/en-US/p/865925
# 865925 fēnix® 7S Pro – Solar Edition
# https://www.garmin.com/en-US/p/735542
# 735542 fēnix® 7S – Standard Edition
# https://www.garmin.com/en-US/p/866191
# 866191 fēnix® 7 Pro – Sapphire Solar Edition
# https://www.garmin.com/en-US/p/865945
# 865945 fēnix® 7X Pro – Solar Edition
# https://www.garmin.com/en-AU/p/682155
# 682155 HRM-Pro™
# https://www.garmin.com/en-US/p/260
# 260 Foretrex® 101
# https://www.garmin.com/en-US/p/257
# 257 Foretrex® 201
# https://www.garmin.com/en-US/p/30026
# 30026 Foretrex® 401
# https://www.garmin.com/en-US/p/30025
# 30025 Foretrex® 301
# https://www.garmin.com/en-US/p/572639
# 572639 Foretrex® 601
# https://www.garmin.com/en-US/p/583825
# 583825 Foretrex® 701 Ballistic Edition
# https://www.garmin.com/en-US/p/858933
# 858933 Foretrex® 801
# https://www.garmin.com/en-US/p/859036
# 859036 Foretrex 901 Ballistic Edition
# https://www.garmin.com/en-US/p/681757
# 681757 vívofit® jr. 2 – Star Wars
# https://www.garmin.com/en-US/p/637006
# 637006 vívofit® jr. 2 – Marvel Spider-Man
# https://www.garmin.com/en-US/p/711489
# 711489 vívofit® jr. 3 – Disney Princess
# epix.html epix™

# %%
df.to_excel('garmin_specs.xlsx', index=False)

# %%
df = pd.read_excel('garmin_specs.xlsx', engine='openpyxl')

# %%
# TODO: create new rows for the following ['Battery Life: Smartwatch', 'Battery Life: GPS', 'Battery Life: Max Battery GPS', 'Battery Life: Expedition GPS', 'Battery Life: Pool and OHR mode', 'Battery Life: Battery Saver Watch Mode', 'Battery Life: All Satellite Systems', 'Battery Life: All Satellite Systems and Multi-band', 'Battery Life: All Satellite Systems and Music', 'Battery Life: GPS + Music', 'Battery Life: UltraTrac', 'Battery Life: Dive mode', 'Battery Life: All-Systems GNSS mode']

# %%
df_temp = df.copy()

# keep only the first 10 columns of the dataframe
# df_temp = df_temp.iloc[:, :10]


category_feature_sort = pd.read_excel('CategoryFeatureSort.xlsx', engine='openpyxl')
# Join the dataframes together based on matching the Category and Feature columns, replacing the index column with the "ConcatVal" col of the category_feature_sort dataframe
df_temp = df_temp.merge(category_feature_sort, how='outer', on=['Category', 'Feature'])
df_temp = df_temp.sort_values(by='ConcatVal')
# drop the CatVal, FeatVal, ConcatVal, Concat columns
df_temp = df_temp.drop(columns=['CatVal', 'FeatVal', 'ConcatVal', 'Concat'])

df_temp.head(10)
# Out:
#          Category             Feature  \
# 664  Product Info        Product Info
# 665  Product Info        Product Name
# 668  Product Info   Product Variation
# 659  Product Info               Image
# 661  Product Info            Main SKU
# 663  Product Info          Product ID
# 662  Product Info               Price
# 667  Product Info         Product URL
# 658  Product Info  DCRainmaker Review
# 669  Product Info        Release Date
#
#                                            fēnix® 3 HR  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5454...
# 668                         Slate Gray with Black Band
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01338-70
# 663                                             545480
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/545480
# 658                                                NaN
# 669                                                NaN
#
#                              Approach® CT10 - Full Set  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/6051...
# 668                                           Full Set
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01994-00
# 663                                             605172
# 662                                             299.99
# 667              https://www.garmin.com/en-US/p/605172
# 658                                                NaN
# 669                                                NaN
#
#                          Approach® CT10 - Starter Pack  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/7981...
# 668                                       Starter Pack
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01994-01
# 663                                             798161
# 662                                              79.99
# 667              https://www.garmin.com/en-US/p/798161
# 658                                                NaN
# 669                                                NaN
#
#                                          Approach® G12  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/7394...
# 668                                        Device Only
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02555-00
# 663                                             739416
# 662                                             149.99
# 667              https://www.garmin.com/en-US/p/739416
# 658                                                NaN
# 669                                                NaN
#
#                                          Approach® G30  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5531...
# 668                                      Approach® G30
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01690-00
# 663                                             553168
# 662                                             249.99
# 667              https://www.garmin.com/en-US/p/553168
# 658                                                NaN
# 669                                                NaN
#
#                                          Approach® G80  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5972...
# 668                                      Approach® G80
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01914-00
# 663                                             597253
# 662                                             499.99
# 667              https://www.garmin.com/en-US/p/597253
# 658                                                NaN
# 669                                                NaN
#
#                                          Approach® R10  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/6953...
# 668                      Portable Golf Launch Monitor
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02356-00
# 663                                             695391
# 662                                             599.99
# 667              https://www.garmin.com/en-US/p/695391
# 658                                                NaN
# 669                                                NaN
#
#                                           Approach® S1  ...  \
# 664                                                NaN  ...
# 665  HYPERLINK("https://www.garmin.com/en-US/p/8306...  ...
# 668                                       Black, U.S.   ...
# 659  IMAGE("https://res.garmin.com/en/products/010-...  ...
# 661                                       010-00932-06  ...
# 663                                              83068  ...
# 662                                                NaN  ...
# 667               https://www.garmin.com/en-US/p/83068  ...
# 658                                                NaN  ...
# 669                                                NaN  ...
#
#                                        vívomove® Sport  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/7421...
# 668    Black Case and Silicone Band with Slate Accents
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02566-00
# 663                                             742133
# 662                                             179.99
# 667              https://www.garmin.com/en-US/p/742133
# 658                                                NaN
# 669                                                NaN
#
#                                        vívomove® Style  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/6628...
# 668  Graphite Aluminum Case with Black Pepper Woven...
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02240-03
# 663                                             662825
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/662825
# 658                                                NaN
# 669                                                NaN
#
#                                        vívomove® Trend  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/7854...
# 668  Cream Gold Stainless Steel Bezel with French G...
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02665-02
# 663                                             785411
# 662                                             299.99
# 667              https://www.garmin.com/en-US/p/785411
# 658                                                NaN
# 669                                                NaN
#
#                                             vívosmart®  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/1548...
# 668                                      Berry (Small)
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01317-03
# 663                                             154886
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/154886
# 658                                                NaN
# 669                                                NaN
#
#                                           vívosmart® 3  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5678...
# 668          Blue with Stainless Buckle (Small/Medium)
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01755-12
# 663                                             567813
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/567813
# 658                                                NaN
# 669                                                NaN
#
#                                           vívosmart® 4  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/6057...
# 668                       Black with Midnight Hardware
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01995-10
# 663                                             605739
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/605739
# 658                                                NaN
# 669                                                NaN
#
#                                           vívosmart® 5  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/7825...
# 668                                              Black
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02645-00
# 663                                             782585
# 662                                             149.99
# 667              https://www.garmin.com/en-US/p/782585
# 658                                                NaN
# 669                                                NaN
#
#                                          vívosmart® HR  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5311...
# 668                            Midnight Blue (Regular)
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01955-08
# 663                                             531166
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/531166
# 658                                                NaN
# 669                                                NaN
#
#                                         vívosmart® HR+  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5487...
# 668                               Black/Shark Fin Gray
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01955-36
# 663                                             548743
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/548743
# 658                                                NaN
# 669                                                NaN
#
#                                             vívosport®
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5746...
# 668                       Fuchsia Focus (Small/Medium)
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01789-11
# 663                                             574602
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/574602
# 658                                                NaN
# 669                                                NaN
#
# [10 rows x 330 columns]

# %%
# load the spec_extras.xlsx file into a dataframe
df_extras = pd.read_excel('spec_extras.xlsx', engine='openpyxl')

# get the index of the row containing "Release Date"
release_date_index = df_temp[df_temp['Feature'] == 'Release Date'].index[0]
review_index = df_temp[df_temp['Feature'] == 'DCRainmaker Review'].index[0]
product_id_index = df_temp[df_temp['Feature'] == 'Product ID'].index[0]

# iterate over each column in the dataframe except for the first two columns
for column in df_temp.columns[2:]:
    # get the value in the column for the product_id_index
    product_id = df_temp[column][product_id_index]
    product_info = df_extras[df_extras['Product ID'] == int(product_id)]

    if not product_info.empty:
        # Extract the Review and Release Date values
        review = product_info['DCRainmaker Review'].values[0]
        release_date = product_info['Release Date'].values[0]
        # set the values in the dataframe with loc
        df_temp.loc[review_index, column] = review
        df_temp.loc[release_date_index, column] = release_date

df_temp.head(10)
# Out:
#          Category             Feature  \
# 664  Product Info        Product Info
# 665  Product Info        Product Name
# 668  Product Info   Product Variation
# 659  Product Info               Image
# 661  Product Info            Main SKU
# 663  Product Info          Product ID
# 662  Product Info               Price
# 667  Product Info         Product URL
# 658  Product Info  DCRainmaker Review
# 669  Product Info        Release Date
#
#                                            fēnix® 3 HR  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5454...
# 668                         Slate Gray with Black Band
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01338-70
# 663                                             545480
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/545480
# 658  https://www.dcrainmaker.com/2016/02/garmin-fen...
# 669                                                NaT
#
#                              Approach® CT10 - Full Set  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/6051...
# 668                                           Full Set
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01994-00
# 663                                             605172
# 662                                             299.99
# 667              https://www.garmin.com/en-US/p/605172
# 658                                                NaN
# 669                                                NaT
#
#                          Approach® CT10 - Starter Pack  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/7981...
# 668                                       Starter Pack
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01994-01
# 663                                             798161
# 662                                              79.99
# 667              https://www.garmin.com/en-US/p/798161
# 658                                                NaN
# 669                                                NaT
#
#                                          Approach® G12  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/7394...
# 668                                        Device Only
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02555-00
# 663                                             739416
# 662                                             149.99
# 667              https://www.garmin.com/en-US/p/739416
# 658                                                NaN
# 669                      2021-03-16T00:00:00.000000000
#
#                                          Approach® G30  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5531...
# 668                                      Approach® G30
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01690-00
# 663                                             553168
# 662                                             249.99
# 667              https://www.garmin.com/en-US/p/553168
# 658                                                NaN
# 669                                                NaT
#
#                                          Approach® G80  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5972...
# 668                                      Approach® G80
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01914-00
# 663                                             597253
# 662                                             499.99
# 667              https://www.garmin.com/en-US/p/597253
# 658                                                NaN
# 669                                                NaT
#
#                                          Approach® R10  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/6953...
# 668                      Portable Golf Launch Monitor
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02356-00
# 663                                             695391
# 662                                             599.99
# 667              https://www.garmin.com/en-US/p/695391
# 658                                                NaN
# 669                      2021-07-08T00:00:00.000000000
#
#                                           Approach® S1  ...  \
# 664                                                NaN  ...
# 665  HYPERLINK("https://www.garmin.com/en-US/p/8306...  ...
# 668                                       Black, U.S.   ...
# 659  IMAGE("https://res.garmin.com/en/products/010-...  ...
# 661                                       010-00932-06  ...
# 663                                              83068  ...
# 662                                                NaN  ...
# 667               https://www.garmin.com/en-US/p/83068  ...
# 658                                                NaN  ...
# 669                                                NaT  ...
#
#                                        vívomove® Sport  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/7421...
# 668    Black Case and Silicone Band with Slate Accents
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02566-00
# 663                                             742133
# 662                                             179.99
# 667              https://www.garmin.com/en-US/p/742133
# 658  https://www.dcrainmaker.com/2023/02/vivomove-w...
# 669                                                NaT
#
#                                        vívomove® Style  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/6628...
# 668  Graphite Aluminum Case with Black Pepper Woven...
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02240-03
# 663                                             662825
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/662825
# 658  https://www.dcrainmaker.com/2023/02/vivomove-w...
# 669                      2019-09-05T00:00:00.000000000
#
#                                        vívomove® Trend  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/7854...
# 668  Cream Gold Stainless Steel Bezel with French G...
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02665-02
# 663                                             785411
# 662                                             299.99
# 667              https://www.garmin.com/en-US/p/785411
# 658  https://www.dcrainmaker.com/2023/02/vivomove-w...
# 669                      2023-02-02T00:00:00.000000000
#
#                                             vívosmart®  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/1548...
# 668                                      Berry (Small)
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01317-03
# 663                                             154886
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/154886
# 658  https://www.dcrainmaker.com/2014/09/vivosmart-...
# 669                                                NaT
#
#                                           vívosmart® 3  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5678...
# 668          Blue with Stainless Buckle (Small/Medium)
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01755-12
# 663                                             567813
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/567813
# 658  https://www.dcrainmaker.com/2017/04/garmin-viv...
# 669                                                NaT
#
#                                           vívosmart® 4  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/6057...
# 668                       Black with Midnight Hardware
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01995-10
# 663                                             605739
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/605739
# 658  https://www.dcrainmaker.com/2018/08/garmin-viv...
# 669                                                NaT
#
#                                           vívosmart® 5  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/7825...
# 668                                              Black
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02645-00
# 663                                             782585
# 662                                             149.99
# 667              https://www.garmin.com/en-US/p/782585
# 658  https://www.dcrainmaker.com/2022/04/garmin-viv...
# 669                      2022-04-20T00:00:00.000000000
#
#                                          vívosmart® HR  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5311...
# 668                            Midnight Blue (Regular)
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01955-08
# 663                                             531166
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/531166
# 658  https://www.dcrainmaker.com/2016/01/garmin-viv...
# 669                                                NaT
#
#                                         vívosmart® HR+  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5487...
# 668                               Black/Shark Fin Gray
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01955-36
# 663                                             548743
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/548743
# 658  https://www.dcrainmaker.com/2016/05/garmin-viv...
# 669                                                NaT
#
#                                             vívosport®
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5746...
# 668                       Fuchsia Focus (Small/Medium)
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01789-11
# 663                                             574602
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/574602
# 658  https://www.dcrainmaker.com/2017/09/garmin-viv...
# 669                                                NaT
#
# [10 rows x 330 columns]

# %%
# Transpose the dataframe
# copy andm then remove the first two columns of the dataframe
df_tempt = df_temp.copy()
release_date_index = df_tempt[df_tempt['Feature'] == 'Release Date'].index[0]
df_tempt = df_tempt.drop(columns=['Category', 'Feature'])

# get the index of the row containing "Release Date"

df_t = df_tempt.T
# sort df_t by column = 667
df_t = df_t.sort_values(by=[release_date_index], na_position='last', ascending=False)
# Transpose the dataframe back
df_tempt = df_t.T
# add the first two columns back to the dataframe
df_tempt = pd.concat([df_temp[['Category', 'Feature']], df_tempt], ignore_index=True, axis=1)
df_tempt.head(10)
# Out:
#               0                   1    \
# 664  Product Info        Product Info
# 665  Product Info        Product Name
# 668  Product Info   Product Variation
# 659  Product Info               Image
# 661  Product Info            Main SKU
# 663  Product Info          Product ID
# 662  Product Info               Price
# 667  Product Info         Product URL
# 658  Product Info  DCRainmaker Review
# 669  Product Info        Release Date
#
#                                                    2    \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/1228...
# 668  Sapphire, Titanium with Spark Orange/Graphite ...
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02904-10
# 663                                            1228429
# 662                                            1099.99
# 667             https://www.garmin.com/en-US/p/1228429
# 658  https://www.dcrainmaker.com/2024/08/garmin-fen...
# 669                      2024-08-27T00:00:00.000000000
#
#                                                    3    \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/8510...
# 668  Carbon Gray DLC Titanium with Black Ultrafit N...
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02751-00
# 663                                             851039
# 662                                             899.99
# 667              https://www.garmin.com/en-US/p/851039
# 658  https://www.dcrainmaker.com/2024/08/garmin-end...
# 669                      2024-08-27T00:00:00.000000000
#
#                                                    4    \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/1228...
# 668  Sapphire, Soft Gold with Fog Gray/Dark Sandsto...
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02903-10
# 663                                            1228493
# 662                                            1099.99
# 667             https://www.garmin.com/en-US/p/1228493
# 658  https://www.dcrainmaker.com/2024/08/garmin-fen...
# 669                      2024-08-27T00:00:00.000000000
#
#                                                    5    \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/1228...
# 668  Sapphire, Titanium with Spark Orange/Graphite ...
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02905-10
# 663                                            1228171
# 662                                            1199.99
# 667             https://www.garmin.com/en-US/p/1228171
# 658  https://www.dcrainmaker.com/2024/08/garmin-fen...
# 669                      2024-08-27T00:00:00.000000000
#
#                                                    6    \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/1390...
# 668  Sapphire, Titanium with Amp Yellow/Graphite Si...
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02907-20
# 663                                            1390829
# 662                                            1199.99
# 667             https://www.garmin.com/en-US/p/1390829
# 658  https://www.dcrainmaker.com/2024/08/garmin-fen...
# 669                      2024-08-27T00:00:00.000000000
#
#                                                    7    \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/1411...
# 668                            Golf Laser Range Finder
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02950-00
# 663                                            1411809
# 662                                             399.99
# 667             https://www.garmin.com/en-US/p/1411809
# 658                                                NaN
# 669                      2024-06-27T00:00:00.000000000
#
#                                                    8    \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/1196...
# 668                           Premium Cycling Computer
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02890-00
# 663                                            1196129
# 662                                             699.99
# 667             https://www.garmin.com/en-US/p/1196129
# 658  https://www.dcrainmaker.com/2024/06/garmin-edg...
# 669                      2024-06-25T00:00:00.000000000
#
#                                                    9    ...  \
# 664                                                NaN  ...
# 665  HYPERLINK("https://www.garmin.com/en-US/p/1055...  ...
# 668                                   Black/Slate Gray  ...
# 659  IMAGE("https://res.garmin.com/en/products/010-...  ...
# 661                                       010-02863-20  ...
# 663                                            1055469  ...
# 662                                             249.99  ...
# 667             https://www.garmin.com/en-US/p/1055469  ...
# 658  https://www.dcrainmaker.com/2024/02/garmin-for...  ...
# 669                      2024-02-20T00:00:00.000000000  ...
#
#                                                    320  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/7114...
# 668                      Black Panther Special Edition
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02441-34
# 663                                             711488
# 662                                              89.99
# 667              https://www.garmin.com/en-US/p/711488
# 658                                                NaN
# 669                                                NaT
#
#                                                    321  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-GB/p/5323...
# 668                   Classic, White with Leather Band
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01597-11
# 663                                             532348
# 662                                             179.99
# 667              https://www.garmin.com/en-GB/p/532348
# 658  https://www.dcrainmaker.com/2016/05/hands-on-w...
# 669                                                NaT
#
#                                                    322  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5835...
# 668  Silver Stainless Steel Case with Dark Brown Em...
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01850-AD
# 663                                             583562
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/583562
# 658  https://www.dcrainmaker.com/2017/09/garmins-vi...
# 669                                                NaT
#
#                                                    323  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/7421...
# 668    Black Case and Silicone Band with Slate Accents
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-02566-00
# 663                                             742133
# 662                                             179.99
# 667              https://www.garmin.com/en-US/p/742133
# 658  https://www.dcrainmaker.com/2023/02/vivomove-w...
# 669                                                NaT
#
#                                                    324  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/1548...
# 668                                      Berry (Small)
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01317-03
# 663                                             154886
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/154886
# 658  https://www.dcrainmaker.com/2014/09/vivosmart-...
# 669                                                NaT
#
#                                                    325  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5678...
# 668          Blue with Stainless Buckle (Small/Medium)
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01755-12
# 663                                             567813
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/567813
# 658  https://www.dcrainmaker.com/2017/04/garmin-viv...
# 669                                                NaT
#
#                                                    326  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/6057...
# 668                       Black with Midnight Hardware
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01995-10
# 663                                             605739
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/605739
# 658  https://www.dcrainmaker.com/2018/08/garmin-viv...
# 669                                                NaT
#
#                                                    327  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5311...
# 668                            Midnight Blue (Regular)
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01955-08
# 663                                             531166
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/531166
# 658  https://www.dcrainmaker.com/2016/01/garmin-viv...
# 669                                                NaT
#
#                                                    328  \
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5487...
# 668                               Black/Shark Fin Gray
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01955-36
# 663                                             548743
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/548743
# 658  https://www.dcrainmaker.com/2016/05/garmin-viv...
# 669                                                NaT
#
#                                                    329
# 664                                                NaN
# 665  HYPERLINK("https://www.garmin.com/en-US/p/5746...
# 668                       Fuchsia Focus (Small/Medium)
# 659  IMAGE("https://res.garmin.com/en/products/010-...
# 661                                       010-01789-11
# 663                                             574602
# 662                                                NaN
# 667              https://www.garmin.com/en-US/p/574602
# 658  https://www.dcrainmaker.com/2017/09/garmin-viv...
# 669                                                NaT
#
# [10 rows x 330 columns]

# %%
df_tempt.to_csv('test.csv', encoding='utf-8-sig', index=False)
